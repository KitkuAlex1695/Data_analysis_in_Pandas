# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
products = pd.read_csv('../data/WA_Sales_Products_2012-14.csv')

# %%
products.head()
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# ...

# %%
groups = products.groupby(by='Retailer country')

# %%
groups.head()
# Out:
#      Retailer country Order method type  Retailer type          Product line  \
# 0       United States               Fax  Outdoors Shop     Camping Equipment
# 1       United States               Fax  Outdoors Shop     Camping Equipment
# 2       United States               Fax  Outdoors Shop     Camping Equipment
# 3       United States               Fax  Outdoors Shop     Camping Equipment
# 4       United States               Fax  Outdoors Shop     Camping Equipment
# ...               ...               ...            ...                   ...
# 8310            Spain               Fax   Sports Store     Camping Equipment
# 8311            Spain               Fax   Sports Store     Camping Equipment
# 8312            Spain               Fax   Sports Store     Camping Equipment
# 8313            Spain               Fax   Sports Store  Personal Accessories
# 8314            Spain               Fax   Sports Store  Personal Accessories
#
# ...

# %%
groups.mean(numeric_only=True).head()
# Out:
#                          Year       Revenue    Quantity  Gross margin
# Retailer country
# Australia         2012.859482  29822.638237  545.915689      0.451174
# Austria           2012.875971  29354.380023  544.330917      0.450913
# Belgium           2012.878976  26134.385420  484.911321      0.448410
# Brazil            2012.878954  33170.824647  595.332117      0.448023
# Canada            2012.839946  41682.874366  746.098936      0.451011

# %%
groups.sum(numeric_only=True)
# Out:
#                       Year       Revenue  Quantity  Gross margin
# Retailer country
# Australia          7377130  1.093000e+08   2000781   1641.822415
# Austria            7773727  1.133666e+08   2102206   1723.839177
# Belgium            7467781  9.695857e+07   1799021   1653.288385
# Brazil             6618346  1.090657e+08   1957452   1466.380765
# Canada            11922051  2.468877e+08   4419144   2662.767825
# China              7350931  2.488232e+08   4596986   1621.792550
# Denmark            4746284  4.789853e+07    962099   1037.909698
# Finland            6861867  1.522220e+08   2786800   1516.908393
# France            11632069  2.195236e+08   4044378   2590.572647
# Germany           10863510  2.007737e+08   3733677   2413.480667
# Italy              8087711  1.546308e+08   2852400   1795.530317
# Japan             10787005  2.816655e+08   5137596   2410.021973
# Korea              6841733  1.585741e+08   2932353   1518.042459
# ...

# %%
groups.count() # will not count nan's
# Out:
#                   Order method type  Retailer type  Product line  \
# Retailer country
# Australia                      3665           3665          3665
# Austria                        3862           3862          3862
# Belgium                        3710           3710          3710
# Brazil                         3288           3288          3288
# Canada                         5923           5923          5923
# China                          3652           3652          3652
# Denmark                        2358           2358          2358
# Finland                        3409           3409          3409
# France                         5779           5779          5779
# Germany                        5397           5397          5397
# Italy                          4018           4018          4018
# Japan                          5359           5359          5359
# Korea                          3399           3399          3399
# ...

# %%
groups.min()
# Out:
#                  Order method type     Retailer type       Product line  \
# Retailer country
# Australia                   E-mail  Department Store  Camping Equipment
# Austria                Sales visit  Department Store  Camping Equipment
# Belgium                        Fax  Department Store  Camping Equipment
# Brazil                      E-mail  Department Store  Camping Equipment
# Canada                      E-mail  Department Store  Camping Equipment
# China                          Fax  Department Store  Camping Equipment
# Denmark                        Fax  Department Store  Camping Equipment
# Finland                Sales visit  Department Store  Camping Equipment
# France                      E-mail  Department Store  Camping Equipment
# Germany                     E-mail  Department Store  Camping Equipment
# Italy                       E-mail  Department Store  Camping Equipment
# Japan                       E-mail  Department Store  Camping Equipment
# ...

# %%
groups.max()
# Out:
#                  Order method type    Retailer type          Product line  \
# Retailer country
# Australia                      Web  Warehouse Store  Personal Accessories
# Austria                        Web  Warehouse Store  Personal Accessories
# Belgium                        Web  Warehouse Store  Personal Accessories
# Brazil                         Web  Warehouse Store  Personal Accessories
# Canada                         Web  Warehouse Store  Personal Accessories
# China                          Web  Warehouse Store  Personal Accessories
# Denmark                        Web  Warehouse Store  Personal Accessories
# Finland                        Web  Warehouse Store  Personal Accessories
# France                         Web  Warehouse Store  Personal Accessories
# Germany                        Web  Warehouse Store  Personal Accessories
# Italy                          Web  Warehouse Store  Personal Accessories
# ...

# %% [markdown]
# The returned above values are just min value for every separate column under the index. The returned row does not need to actually exist in the frame:

# %%
products.loc[(products['Retailer country'] == 'Australia') & 
             (products['Order method type'] == 'Web') &
             (products['Retailer type'] == 'Warehouse Store') &
             (products['Product line'] == 'Personal Accessories') &
             (products['Product type'] == 'Woods')
             ]
# Out:
# Empty DataFrame
# Columns: [Retailer country, Order method type, Retailer type, Product line, Product type, Product, Year, Quarter, Revenue, Quantity, Gross margin]
# Index: []

# %%
groups['Revenue'].sum().head()
# Out:
# Retailer country
# Australia    1.093000e+08
# Austria      1.133666e+08
# Belgium      9.695857e+07
# Brazil       1.090657e+08
# Canada       2.468877e+08
# Name: Revenue, dtype: float64

# %%
groups[['Revenue', 'Quantity']].mean().head()
# Out:
#                        Revenue    Quantity
# Retailer country
# Australia         29822.638237  545.915689
# Austria           29354.380023  544.330917
# Belgium           26134.385420  484.911321
# Brazil            33170.824647  595.332117
# Canada            41682.874366  746.098936
