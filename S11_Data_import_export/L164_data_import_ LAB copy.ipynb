# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
url = '../data/mobile_internet_use_isoc_cimobi_frq.tsv'

# %%
df = pd.read_csv(url, sep='\t')
df.head()
# Out:
#        indic_is,ind_type,unit,time\geo EU28  EU27  EU15   EA   BE    BG   CZ   \
# 0       I_IHDDAY,CB_EU_FOR,PC_IND,2012   15    15    16   12   15    : u  : u
# 1   I_IHDDAY,CB_EU_FOR,PC_IND_IU3,2012   21    21    21   17   19    : u  : u
# 2  I_IHDDAY,CB_EU_FOR,PC_IND_IUHD,2012   57    57    57   55   48    : u  : u
# 3       I_IHDDAY,CB_EXT_EU,PC_IND,2012   21    21    22   13   11   25 u   :
# 4   I_IHDDAY,CB_EXT_EU,PC_IND_IU3,2012   28    28    29   19   15   28 u   :
#
#     DK   DE   ...  SI    SK    FI    SE    UK    IS    NO  ME  MK  TR
# 0   22    7   ...  : u  14 u  35 u  35 u   39    16   31 u  :   :   :
# 1   22   11   ...  : u  17 u  36 u  40 u  46 u   17   32 u  :   :   :
# 2  49 u  60   ...  : u   : u   : u   : u  60 u  40 u  50 u  :   :   :
# 3   35   12   ...   3    : u   22    39    39   16 u  32 u  :   :   :
# 4   39   14   ...   5    : u  24 u   42    43   17 u  32 u  :   :   :
#
# [5 rows x 38 columns]

# %%
df_desc = df['indic_is,ind_type,unit,time\\geo'].str.split(',', expand=True)
df_desc.head()
# Out:
#           0          1            2     3
# 0  I_IHDDAY  CB_EU_FOR       PC_IND  2012
# 1  I_IHDDAY  CB_EU_FOR   PC_IND_IU3  2012
# 2  I_IHDDAY  CB_EU_FOR  PC_IND_IUHD  2012
# 3  I_IHDDAY  CB_EXT_EU       PC_IND  2012
# 4  I_IHDDAY  CB_EXT_EU   PC_IND_IU3  2012

# %%
df_desc.rename(mapper={0 : 'idnic_is',
                       1 : 'ind_type',
                       2 : 'unit',
                       3 : 'time_geo'},
                       axis='columns',
                       inplace=True)
df_desc.head()
# Out:
#    idnic_is   ind_type         unit time_geo
# 0  I_IHDDAY  CB_EU_FOR       PC_IND     2012
# 1  I_IHDDAY  CB_EU_FOR   PC_IND_IU3     2012
# 2  I_IHDDAY  CB_EU_FOR  PC_IND_IUHD     2012
# 3  I_IHDDAY  CB_EXT_EU       PC_IND     2012
# 4  I_IHDDAY  CB_EXT_EU   PC_IND_IU3     2012

# %%
df_desc.columns
# Out:
# Index(['idnic_is', 'ind_type', 'unit', 'time_geo'], dtype='object')

# %%
df_desc = df_desc.join(df).drop(labels=df.columns[0], 
                      axis='columns')

# %%
df_desc
# Out:
#       idnic_is   ind_type         unit time_geo EU28  EU27  EU15   EA   BE   \
# 0     I_IHDDAY  CB_EU_FOR       PC_IND     2012   15    15    16   12   15
# 1     I_IHDDAY  CB_EU_FOR   PC_IND_IU3     2012   21    21    21   17   19
# 2     I_IHDDAY  CB_EU_FOR  PC_IND_IUHD     2012   57    57    57   55   48
# 3     I_IHDDAY  CB_EXT_EU       PC_IND     2012   21    21    22   13   11
# 4     I_IHDDAY  CB_EXT_EU   PC_IND_IU3     2012   28    28    29   19   15
# ..         ...        ...          ...      ...   ...   ...   ...  ...  ...
# 442  I_IHDLTWK    Y75_MAX   PC_IND_IU3     2012    :     :     :    :    :
# 443  I_IHDLTWK    Y75_MAX  PC_IND_IUHD     2012    :     :     :    :    :
# 444   I_IHDUSE  CB_EU_FOR       PC_IND     2012   22    22    22   18   26
# 445   I_IHDUSE  CB_EU_FOR   PC_IND_IU3     2012   30    30    30   25   33
# 446   I_IHDUSE  CB_EU_FOR  PC_IND_IUHD     2012   82    82    82   81   82
#
# ...

# %%
url = '../data/world-heritage-unesco-list.json'

# %%
pd.read_json(url).sort_values(by='datasetid')
# Out:
#                        datasetid                                  recordid  \
# 0     world-heritage-unesco-list  ff1f5b718ce2ee87f18dfaf20610f257979f2f4a
# 693   world-heritage-unesco-list  77507a213c1e0d5888282019f58a5be5f6781637
# 694   world-heritage-unesco-list  aa8750a0d106e4e7f2c158fd2c97a8fe698af5cf
# 695   world-heritage-unesco-list  a172710271f7561c4e3ed6fda6e14b6f1ffe0820
# 696   world-heritage-unesco-list  175d5841a3988db2fb3e2020cedc631875765ebd
# ...                          ...                                       ...
# 356   world-heritage-unesco-list  d8a670d1fc3f1f1cdb55f63d2f662eb330fafab8
# 357   world-heritage-unesco-list  0f1521d04575103e615999878640fecd42b0532e
# 358   world-heritage-unesco-list  b0fed5690cb2ce5cea2c192516e953670d746911
# 360   world-heritage-unesco-list  3852dea1d26432af0d2193f7d0a46dbb48fdd5ec
# 1051  world-heritage-unesco-list  e0008b2c6110a51915e4314b598e736676f0f74d
#
#                                                  fields  \
# ...
