# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
frame = pd.read_csv('..//data/mcdonalds.csv', usecols=['Item', 'Category', 'Serving Size', 'Calories', 'TotalFat'])

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
has400CalorMore = frame['Calories'] >= 400
has400CalorMore
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 255     True
# 256     True
# 257    False
# 258     True
# 259     True
# Name: Calories, Length: 260, dtype: bool

# %%
frame.where(has400CalorMore)
# Out:
#                Category                                               Item  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257                 NaN                                                NaN
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  TotalFat
# ...

# %% [markdown]
# where returns data in original shape

# %%
frame.where(has400CalorMore).dropna(how='all')
# Out:
#                Category                                               Item  \
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 5             Breakfast                               Steak & Egg McMuffin
# 6             Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7             Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# ..                  ...                                                ...
# 254  Smoothies & Shakes                McFlurry with M&M’s Candies (Snack)
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  TotalFat
# ...

# %%
frame[has400CalorMore]
# Out:
#                Category                                               Item  \
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 5             Breakfast                               Steak & Egg McMuffin
# 6             Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7             Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# ..                  ...                                                ...
# 254  Smoothies & Shakes                McFlurry with M&M’s Candies (Snack)
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  TotalFat
# ...

# %%
frame.query('Category == "Desserts"')
# Out:
#      Category                   Item     Serving Size  Calories  TotalFat
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250      13.0
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160       8.0
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150       6.0
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45       1.5
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330       9.0
# 108  Desserts     Hot Caramel Sundae   6.4 oz (182 g)       340       8.0
# 109  Desserts      Strawberry Sundae   6.3 oz (178 g)       280       6.0

# %%
frame.query('Category in ["Desserts","Beverages"]').head()
# Out:
#      Category                   Item     Serving Size  Calories  TotalFat
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250      13.0
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160       8.0
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150       6.0
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45       1.5
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330       9.0

# %%
frame.query('Category == "Desserts" and Calories <200')
# Out:
#      Category                   Item     Serving Size  Calories  TotalFat
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160       8.0
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150       6.0
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45       1.5
