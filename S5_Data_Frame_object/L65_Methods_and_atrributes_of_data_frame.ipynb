# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
frame = pd.read_csv('../data/mcdonalds.csv', usecols=['Item', 'Category', 'Calories', 'TotalFat', 'Sugars', 'Protein', 'Cholesterol'])

# %%
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein
# 0          260       3       17
# 1           25       3       18
# 2           45       2       14
# 3          285       2       21
# 4           50       2       21

# %%
frame.Item.head()
# Out:
# 0                        Egg McMuffin
# 1                   Egg White Delight
# 2                    Sausage McMuffin
# 3           Sausage McMuffin with Egg
# 4    Sausage McMuffin with Egg Whites
# Name: Item, dtype: object

# %%
frame['Item'].head()
# Out:
# 0                        Egg McMuffin
# 1                   Egg White Delight
# 2                    Sausage McMuffin
# 3           Sausage McMuffin with Egg
# 4    Sausage McMuffin with Egg Whites
# Name: Item, dtype: object

# %%
frame['TotalFat0'] = 0

# %%
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein  TotalFat0
# 0          260       3       17          0
# 1           25       3       18          0
# 2           45       2       14          0
# 3          285       2       21          0
# 4           50       2       21          0

# %%
SugarAndFat = frame.Sugars + frame.TotalFat

# %%
frame['SugarAndFat'] = SugarAndFat

# %%
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein  TotalFat0  SugarAndFat
# 0          260       3       17          0         16.0
# 1           25       3       18          0         11.0
# 2           45       2       14          0         25.0
# 3          285       2       21          0         30.0
# 4           50       2       21          0         25.0

# %%
frame['SugarAndProtein'] = frame.Sugars + frame.Protein

# %% [markdown]
# If one want to insert column in other position than at the end, he shall use the .insert method

# %%
frame.insert(loc=2, 
             column='SPF', 
             value=frame.SugarAndProtein + frame.TotalFat)

# %%
frame.head()
# Out:
#     Category                              Item   SPF  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  33.0       300      13.0
# 1  Breakfast                 Egg White Delight  29.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  39.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  51.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0       400      23.0
#
#    Cholesterol  Sugars  Protein  TotalFat0  SugarAndFat  SugarAndProtein
# 0          260       3       17          0         16.0               20
# 1           25       3       18          0         11.0               21
# 2           45       2       14          0         25.0               16
# 3          285       2       21          0         30.0               23
# 4           50       2       21          0         25.0               23

# %%
del frame['SugarAndProtein']

# %%
frame.head()
# Out:
#     Category                              Item   SPF  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  33.0       300      13.0
# 1  Breakfast                 Egg White Delight  29.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  39.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  51.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0       400      23.0
#
#    Cholesterol  Sugars  Protein  TotalFat0  SugarAndFat
# 0          260       3       17          0         16.0
# 1           25       3       18          0         11.0
# 2           45       2       14          0         25.0
# 3          285       2       21          0         30.0
# 4           50       2       21          0         25.0

# %%
# del frame.SugarAndFat Will not work

# %%
frame = frame.drop(columns=['SugarAndFat']) # using .drop method

# %%
frame.head()
# Out:
#     Category                              Item   SPF  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin  33.0       300      13.0
# 1  Breakfast                 Egg White Delight  29.0       250       8.0
# 2  Breakfast                  Sausage McMuffin  39.0       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg  51.0       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0       400      23.0
#
#    Cholesterol  Sugars  Protein  TotalFat0
# 0          260       3       17          0
# 1           25       3       18          0
# 2           45       2       14          0
# 3          285       2       21          0
# 4           50       2       21          0

# %%
frame.drop(labels='SPF',
           axis=1,                   # 1 for column, 0 for row
           inplace=True
           )

# %%
frame.head()
# Out:
#     Category                              Item  Calories  TotalFat  \
# 0  Breakfast                      Egg McMuffin       300      13.0
# 1  Breakfast                 Egg White Delight       250       8.0
# 2  Breakfast                  Sausage McMuffin       370      23.0
# 3  Breakfast         Sausage McMuffin with Egg       450      28.0
# 4  Breakfast  Sausage McMuffin with Egg Whites       400      23.0
#
#    Cholesterol  Sugars  Protein  TotalFat0
# 0          260       3       17          0
# 1           25       3       18          0
# 2           45       2       14          0
# 3          285       2       21          0
# 4           50       2       21          0
