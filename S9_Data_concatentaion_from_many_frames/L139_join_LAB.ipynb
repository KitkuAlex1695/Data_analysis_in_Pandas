# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
customer_names = pd.read_csv('../data/northwind/customers.csv', 
                             usecols=['CustomerID', 'CompanyName'])
customer_cities = pd.read_csv('../data/northwind/customers.csv', 
                             usecols=['CustomerID', 'City', 'Country'])

# %%
len(customer_names)
# Out:
# 91

# %%
len(customer_cities)
# Out:
# 91

# %%
customer_names.set_index('CustomerID', inplace=True)
customer_cities.set_index('CustomerID', inplace=True)

# %%
customer_names.join(customer_cities)
# Out:
#                                    CompanyName          City  Country
# CustomerID
# ALFKI                      Alfreds Futterkiste        Berlin  Germany
# ANATR       Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# ANTON                 Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# AROUT                          Around the Horn        London       UK
# BERGS                      Berglunds snabbk?¶p        Lule??   Sweden
# ...                                        ...           ...      ...
# WARTH                           Wartian Herkku          Oulu  Finland
# WELLI                   Wellington Importadora       Resende   Brazil
# WHITC                     White Clover Markets       Seattle      USA
# WILMK                              Wilman Kala      Helsinki  Finland
# WOLZA                           Wolski  Zajazd      Warszawa   Poland
#
# [91 rows x 3 columns]

# %%
customer_names.reset_index(inplace=True)

# %%
customer_names
# Out:
#     index CustomerID                         CompanyName
# 0       0      ALFKI                 Alfreds Futterkiste
# 1       1      ANATR  Ana Trujillo Emparedados y helados
# 2       2      ANTON            Antonio Moreno Taquer?­a
# 3       3      AROUT                     Around the Horn
# 4       4      BERGS                 Berglunds snabbk?¶p
# ..    ...        ...                                 ...
# 86     86      WARTH                      Wartian Herkku
# 87     87      WELLI              Wellington Importadora
# 88     88      WHITC                White Clover Markets
# 89     89      WILMK                         Wilman Kala
# 90     90      WOLZA                      Wolski  Zajazd
#
# [91 rows x 3 columns]

# %%
customer_cities
# Out:
#                     City  Country
# CustomerID
# ALFKI             Berlin  Germany
# ANATR       M?©xico D.F.   Mexico
# ANTON       M?©xico D.F.   Mexico
# AROUT             London       UK
# BERGS             Lule??   Sweden
# ...                  ...      ...
# WARTH               Oulu  Finland
# WELLI            Resende   Brazil
# WHITC            Seattle      USA
# WILMK           Helsinki  Finland
# WOLZA           Warszawa   Poland
#
# [91 rows x 2 columns]

# %%
customer_names.join(other=customer_cities, on='CustomerID')
# Out:
#     index CustomerID                         CompanyName          City  \
# 0       0      ALFKI                 Alfreds Futterkiste        Berlin
# 1       1      ANATR  Ana Trujillo Emparedados y helados  M?©xico D.F.
# 2       2      ANTON            Antonio Moreno Taquer?­a  M?©xico D.F.
# 3       3      AROUT                     Around the Horn        London
# 4       4      BERGS                 Berglunds snabbk?¶p        Lule??
# ..    ...        ...                                 ...           ...
# 86     86      WARTH                      Wartian Herkku          Oulu
# 87     87      WELLI              Wellington Importadora       Resende
# 88     88      WHITC                White Clover Markets       Seattle
# 89     89      WILMK                         Wilman Kala      Helsinki
# 90     90      WOLZA                      Wolski  Zajazd      Warszawa
#
#     Country
# 0   Germany
# 1    Mexico
# 2    Mexico
# 3        UK
# 4    Sweden
# ..      ...
# 86  Finland
# 87   Brazil
# 88      USA
# 89  Finland
# 90   Poland
#
# [91 rows x 5 columns]
