# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
mrbean = pd.read_csv('../data/mrbean_facebook_statuses_join.csv', 
                     usecols=['status_message_mrbean','status_type','num_likes'])

# %%
nasa = pd.read_csv('../data/nasa_facebook_statuses_join.csv',
                   usecols=['status_message_nasa','status_type','num_likes'])

# %%
mrbean.head()
# Out:
#                                status_message_mrbean status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa.tail()
# Out:
#                                    status_message_nasa status_type  num_likes
# 758  You've never seen Pluto like this before! New ...       photo      39355
# 759  Our cooperative field study in East Asia advan...       photo      11835
# 760  After spending a #YearInSpace, astronaut Scott...       photo      15567
# 761  Gravitational waves, predicted by Einstein and...       photo      41584
# 762  Have you ever used a GPS to help you get somew...       photo      12793

# %%
# fb = mrbean.append(nasa, sort=True) -> withdrawn
fb = pd.concat([mrbean, nasa]).sort_index()

# %%
fb.head()
# Out:
#                                status_message_mrbean status_type  num_likes  \
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 0                                                NaN       photo       5142
# 1                                                NaN       photo     114008
# 1                                                NaN       photo      19074
# 2                                                NaN       photo     218579
#
#                                  status_message_nasa
# 0                                                NaN
# 0  This morning, the #RockOn mission with student...
# 1                                                NaN
# 1  Pluto's largest moon, Charon, is home to an un...
# 2                                                NaN

# %%
fb.tail()
# Out:
#     status_message_mrbean status_type  num_likes  \
# 758                   NaN       photo      39355
# 759                   NaN       photo      11835
# 760                   NaN       photo      15567
# 761                   NaN       photo      41584
# 762                   NaN       photo      12793
#
#                                    status_message_nasa
# 758  You've never seen Pluto like this before! New ...
# 759  Our cooperative field study in East Asia advan...
# 760  After spending a #YearInSpace, astronaut Scott...
# 761  Gravitational waves, predicted by Einstein and...
# 762  Have you ever used a GPS to help you get somew...

# %%
fb.loc[0]
# Out:
#                                status_message_mrbean status_type  num_likes  \
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 0                                                NaN       photo       5142
#
#                                  status_message_nasa
# 0                                                NaN
# 0  This morning, the #RockOn mission with student...

# %%
# fb = mrbean.append(nasa, sort=True, ignore_index=True) -> withdrawn
fb = pd.concat([mrbean, nasa],ignore_index=True)

# %%
fb.loc[0]
# Out:
# status_message_mrbean    It's time for Mr Bean and Teddy to get ready f...
# status_type                                                          video
# num_likes                                                            16079
# status_message_nasa                                                    NaN
# Name: 0, dtype: object

# %%
mrbean.rename(columns={'status_message_mrbean' : 'status_message'}, inplace=True)
nasa.rename(columns={'status_message_nasa' : 'status_message'}, inplace=True)

# fb = mrbean.append(nasa, sort=True, ignore_index=True) -> withdrawn
fb = pd.concat([mrbean, nasa],ignore_index=True)

# %%
fb
# Out:
#                                         status_message status_type  num_likes
# 0    It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                  NaN       photo     114008
# 2                                                  NaN       photo     218579
# 3    Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                  NaN       photo     215591
# ..                                                 ...         ...        ...
# 814  You've never seen Pluto like this before! New ...       photo      39355
# 815  Our cooperative field study in East Asia advan...       photo      11835
# 816  After spending a #YearInSpace, astronaut Scott...       photo      15567
# 817  Gravitational waves, predicted by Einstein and...       photo      41584
# 818  Have you ever used a GPS to help you get somew...       photo      12793
#
# [819 rows x 3 columns]
