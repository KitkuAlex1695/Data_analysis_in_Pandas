# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
products = pd.read_csv('../data/northwind/products.csv',
                       usecols=['ProductID', 'ProductName', 'CategoryID', 'SupplierID'])
categories = pd.read_csv('../data/northwind/categories1.csv',
                       usecols=['CategoryID', 'CategoryName'],
                       index_col='CategoryID')
suppliers = pd.read_csv('../data/northwind/suppliers.csv',
                        usecols=['SupplierID', 'CompanyName', 'City'])

# %%
products.head(3)
# Out:
#    ProductID    ProductName  SupplierID  CategoryID
# 0          1           Chai           1           1
# 1          2          Chang           1           1
# 2          3  Aniseed Syrup           1           2

# %%
categories.head(3)
# Out:
#            CategoryName
# CategoryID
# 1             Beverages
# 2            Condiments
# 3           Confections

# %%
suppliers.head(3)
# Out:
#    SupplierID                 CompanyName         City
# 0           1              Exotic Liquids       London
# 1           2  New Orleans Cajun Delights  New Orleans
# 2           3   Grandma Kelly's Homestead    Ann Arbor

# %%
prod_cat = products.merge(right=categories, left_on='CategoryID' ,right_index=True)

# %%
prod_cat
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                             Chai           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#    CategoryName
# 0     Beverages
# 1     Beverages
# 2    Condiments
# 3    Condiments
# 4    Condiments
# ..          ...
# 72      Seafood
# 73      Produce
# 74    Beverages
# 75    Beverages
# 76   Condiments
#
# [77 rows x 5 columns]

# %%
prod_cat_sup = prod_cat.merge(right=suppliers, on='SupplierID')

# %%
prod_cat_sup
# Out:
#     ProductID                      ProductName  SupplierID  CategoryID  \
# 0           1                             Chai           1           1
# 1           2                            Chang           1           1
# 2           3                    Aniseed Syrup           1           2
# 3           4     Chef Anton's Cajun Seasoning           2           2
# 4           5           Chef Anton's Gumbo Mix           2           2
# ..        ...                              ...         ...         ...
# 72         73                       Röd Kaviar          17           8
# 73         74                    Longlife Tofu           4           7
# 74         75             Rhönbräu Klosterbier          12           1
# 75         76                     Lakkalikööri          23           1
# 76         77  Original Frankfurter grüne Soße          12           2
#
#    CategoryName                        CompanyName          City
# 0     Beverages                     Exotic Liquids        London
# 1     Beverages                     Exotic Liquids        London
# 2    Condiments                     Exotic Liquids        London
# 3    Condiments         New Orleans Cajun Delights   New Orleans
# 4    Condiments         New Orleans Cajun Delights   New Orleans
# ..          ...                                ...           ...
# 72      Seafood                  Svensk Sjöföda AB     Stockholm
# 73      Produce                      Tokyo Traders         Tokyo
# 74    Beverages  Plutzer Lebensmittelgroßmärkte AG     Frankfurt
# 75    Beverages                          Karkki Oy  Lappeenranta
# 76   Condiments  Plutzer Lebensmittelgroßmärkte AG     Frankfurt
#
# [77 rows x 7 columns]
