# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
f_2015 = pd.read_csv('../data/Fortune_500_2015.csv',
                     usecols=['rank', 'company'])
f_2016 = pd.read_csv('../data/Fortune_500_2016.csv',
                     usecols=['rank', 'company'])

# %%
f_2015
# Out:
#      rank                    company
# 0       1                    Walmart
# 1       2                Exxon Mobil
# 2       3                    Chevron
# 3       4         Berkshire Hathaway
# 4       5                      Apple
# ..    ...                        ...
# 495   496  Pioneer Natural Resources
# 496   497          Wyndham Worldwide
# 497   498              Owens Corning
# 498   499                  Alleghany
# 499   500      McGraw Hill Financial
#
# [500 rows x 2 columns]

# %%
companies_2015_2016 = f_2015.merge(f_2016, on='company' , how='inner', indicator=True, suffixes=['_2015', '_2016'])

# %%
companies_2015_2016
# Out:
#      rank_2015                company  rank_2016 _merge
# 0            1                Walmart          1   both
# 1            2            Exxon Mobil          2   both
# 2            3                Chevron         14   both
# 3            4     Berkshire Hathaway          4   both
# 4            5                  Apple          3   both
# ..         ...                    ...        ...    ...
# 461        493    Insight Enterprises        474   both
# 462        494  Alliance Data Systems        404   both
# 463        495       LifePoint Health        430   both
# 464        497      Wyndham Worldwide        466   both
# 465        498          Owens Corning        480   both
#
# [466 rows x 4 columns]

# %%
companies_2015_2016.where(companies_2015_2016['company'] == 'Microsoft').dropna()
# Out:
#     rank_2015    company  rank_2016 _merge
# 30       31.0  Microsoft       25.0   both

# %%
companies_2015_2016 = f_2015.merge(f_2016, on='company' , how='outer', indicator=True, suffixes=['_2015', '_2016'])

# %%
companies_2015_2016.head(10)
# Out:
#    rank_2015                 company  rank_2016      _merge
# 0       98.0                      3M       93.0        both
# 1      444.0  A-Mark Precious Metals      426.0        both
# 2        NaN          ABM Industries      485.0  right_only
# 3      251.0                     ADP      248.0        both
# 4      343.0                   AECOM      156.0        both
# 5      178.0                     AES      190.0        both
# 6      296.0                    AGCO      360.0        both
# 7      465.0           AGL Resources        NaN   left_only
# 8       46.0                     AIG       49.0        both
# 9      415.0        AK Steel Holding      383.0        both

# %%
filter_2015 = companies_2015_2016['_merge'] == 'left_only'
filter_2016 = companies_2015_2016['_merge'] == 'right_only'

# %%
only_2015 = companies_2015_2016[filter_2015]
only_2016 = companies_2015_2016[filter_2016]

# %%
only_2015
# Out:
#      rank_2015                              company  rank_2016     _merge
# 7        465.0                        AGL Resources        NaN  left_only
# 10       492.0                          ARRIS Group        NaN  left_only
# 15       473.0               Advanced Micro Devices        NaN  left_only
# 18       389.0                 Agilent Technologies        NaN  left_only
# 22       125.0                                Alcoa        NaN  left_only
# 23       499.0                            Alleghany        NaN  left_only
# 24       380.0                             Allergan        NaN  left_only
# 78       373.0                     Blackstone Group        NaN  left_only
# 85       406.0                     Buckeye Partners        NaN  left_only
# 98       328.0                Caesars Entertainment        NaN  left_only
# 100      457.0  Calumet Specialty Products Partners        NaN  left_only
# 117      215.0                                Chubb        NaN  left_only
# ...

# %%
only_2016
# Out:
#      rank_2015                       company  rank_2016      _merge
# 2          NaN                ABM Industries      485.0  right_only
# 20         NaN                        Airgas      484.0  right_only
# 49         NaN                       Arconic      126.0  right_only
# 51         NaN           Arthur J. Gallagher      471.0  right_only
# 69         NaN                       Baxalta      420.0  right_only
# 75         NaN                      Big Lots      495.0  right_only
# 86         NaN             Burlington Stores      500.0  right_only
# 119        NaN          Cincinnati Financial      499.0  right_only
# 122        NaN      Citizens Financial Group      486.0  right_only
# 126        NaN   Coca-Cola European Partners      397.0  right_only
# 137        NaN          Constellation Brands      429.0  right_only
# 182        NaN  Envision Healthcare Holdings      469.0  right_only
# 201        NaN      First American Financial      497.0  right_only
# ...
